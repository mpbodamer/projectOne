# %%
import folium
import pandas as pd

# %%
la_coordinates = (34.0407, -118.2468)
restaurant_data = pd.read_csv('yelp_data.csv')
restaurant_data.head()
# Out:
#        category is_closed   latitude   longitude        name  rating  \
# 0      southern     False  34.042333 -118.263475         NaN     2.5
# 1  tradamerican       NaN  34.090626 -118.345579  Mimimyunga     3.0
# 2      desserts     False  34.071340 -118.356870         NaN     3.0
# 3       italian     False  34.059092 -118.420453         NaN     3.0
# 4  tradamerican     False  34.090626 -118.345579         NaN     3.0
#
#    review_count
# 0           249
# 1            61
# 2          1398
# 3           498
# 4            61

# %%
# for speed purposes
MAX_RECORDS = 1000
  
# create empty map zoomed in on San Francisco
test = folium.Map(location=la_coordinates, zoom_start=12)

# %%
# import libraries
import folium
import pandas as pd
 
# Make a data frame with dots to show on the map
data = restaurant_data[['latitude','longitude']].head(20)
 
# Make an empty map
mapx = folium.Map(location=[34.0407, -118.2468], tiles="Mapbox Bright", zoom_start=12)
 
# I can add marker one by one on the map
for i in range(0,len(data)):
    folium.Marker([data.iloc[i]['longitude'], data.iloc[i]['latitude']]).add_to(m)
 

m.save('map1.html')

# %%
# add a marker for every record in the filtered data, use a clustered view
for key, each in restaurant_data.iterrows():
#     print(each[1]['long'],each[1]['lat'])
#    test.simple_marker(
#        location = [each[1]['longitude'],each[1]['latitude']], 
#        clustered_marker = True)    
  
#display(map)

# restaurant_data.head()
# Out:
# 0
# category        southern
# is_closed          False
# latitude         34.0423
# longitude       -118.263
# name                 NaN
# rating               2.5
# review_count         249
# Name: 0, dtype: object
# 1
# category        tradamerican
# is_closed                NaN
# latitude             34.0906
# longitude           -118.346
# name              Mimimyunga
# rating                     3
# review_count              61
# Name: 1, dtype: object
# 2
# category        desserts
# is_closed          False
# latitude         34.0713
# longitude       -118.357
# name                 NaN
# rating                 3
# review_count        1398
# Name: 2, dtype: object
# 3
# category        italian
# is_closed         False
# latitude        34.0591
# longitude       -118.42
# name                NaN
# rating                3
# review_count        498
# Name: 3, dtype: object
# 4
# category        tradamerican
# is_closed              False
# latitude             34.0906
# ...

# %%
for each in restaurant_data.head().iterrows():
    print(each[1]['longitude'],each[1]['latitude'])

# %%
# %history
# Out:
# import folium
# import pandas as pd
# !pip install folium
# import folium
# import pandas as pd
#
# import folium
# import pandas as pd
# la_coordinates = (34.0407, -118.2468)
# restaurant_data = pd.read_csv('la_RESTAURANT_AND_MARKET_INSPECTIONS.csv')
# #modules
# import folium
# import pandas as pd
# import csv
# la_coordinates = (34.0407, -118.2468)
# restaurant_data = pd.read_csv('la_RESTAURANT_AND_MARKET_INSPECTIONS.csv')
# restaurant_data.head()
# la_coordinates = (34.0407, -118.2468)
# restaurant_data = pd.read_csv('la_RESTAURANT_AND_MARKET_INSPECTIONS.csv')
# restaurant_data.head()
# # look for missing values
# crime_df.count()
# # look for missing values
# restaurant_data.count()
# # drop null rows
# no_null_restaurant_data = restaurant_data.dropna(how='any')
# # verify counts
# no_null_crime_df.count()
# # verify counts
# no_null_restaurant_data.count()
# # create a new variable to include only the data that are important for analysis
#
# ...
