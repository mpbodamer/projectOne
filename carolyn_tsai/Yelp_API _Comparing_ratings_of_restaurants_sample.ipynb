# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
from pprint import pprint
from statistics import mean


# Import API key
from api_keys import yelp_api_key

# Define endpoint, API key, headers, and parameters

base_url = "https://api.yelp.com/v3/businesses/search"

api_key = yelp_api_key

headers = {"Authorization" : "bearer %s" % api_key}

params_ny = {"term" : "bagel",
          "limit" : 50,
          "location" : "New York City",
          "sort_by" : "rating", 
         }

# %%
# Get the responses for the paramenters set

response_ny = requests.get(url = base_url, params = params_ny, headers = headers).json()
pprint(response)
# Out:
# {'businesses': [{'alias': 'prospect-provisions-brooklyn',
#                  'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#                                 {'alias': 'breakfast_brunch',
#                                  'title': 'Breakfast & Brunch'},
#                                 {'alias': 'bagels', 'title': 'Bagels'}],
#                  'coordinates': {'latitude': 40.6649938946527,
#                                  'longitude': -73.9930540403283},
#                  'display_phone': '(347) 763-2777',
#                  'distance': 4499.151062407403,
#                  'id': 'T55YbUuuYSmBtoN3b2mfzA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Nny7yksWTA4DvrhvS4i7mA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '597 4th Ave',
#                               'address2': None,
#                               'address3': None,
#                               'city': 'Brooklyn',
# ...

# %%
# Get the rating information for the businesses

ratings_ny = []

for business in response_ny["businesses"]:
    ratings.append(business["rating"])

ratings_ny
# Out:
# [5.0,
#  4.5,
#  4.5,
#  4.5,
#  4.5,
#  4.5,
#  4.5,
#  4.5,
#  4.5,
#  4.0,
#  4.5,
#  4.5,
#  4.0,
#  4.0,
#  4.0,
#  4.5,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.5,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  3.5,
#  3.5,
#  4.0,
#  3.5,
#  3.5]

# %%
# Find the average of the ratings to compare with rating of restaurants in a different city

average_ratings_ny = mean(ratings_ny)
average_ratings_ny
# Out:
# 4.1

# %%
# Do the same for another city, I chose San Francisco

params_sf = {"term" : "bagel",
          "limit" : 50,
          "location" : "San Francisco",
          "sort_by" : "rating", 
         }

response_sf = requests.get(url = base_url, params = params_sf, headers = headers).json()

ratings_sf = []

for business in response_sf["businesses"]:
    ratings_sf.append(business["rating"])

average_ratings_sf = mean(ratings_sf)
average_ratings_sf
# Out:
# 4.19

# %%
# Verify that different restaurants were selected

pprint(response_sf)
# Out:
# {'businesses': [{'alias': 'neighbor-bakehouse-san-francisco',
#                  'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#                  'coordinates': {'latitude': 37.759631,
#                                  'longitude': -122.388171},
#                  'display_phone': '(415) 549-7716',
#                  'distance': 4246.220166417273,
#                  'id': '4vrX5JhM1D3dTiL4DU5clQ',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/6-jv_83kA3k-2mgH-RhjQA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '2343 3rd St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['2343 3rd St',
#                                                   'San Francisco, CA 94107'],
# ...
